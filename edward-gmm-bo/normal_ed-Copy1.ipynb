# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import tensorflow as tf
import scipy.stats as sps
from sklearn.cross_validation import train_test_split

import edward as ed

from edward.models import PointMass,WishartFull, WishartCholesky, MultivariateNormalCholesky, MultivariateNormalFull
# Out:
# /home/folzd/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# %load_ext autoreload

# %%
ed.__version__, tf.__version__, np.__version__
# Out:
# ('1.2.1', '1.0.0', '1.11.0')

# %%
D = 2
N = 10000
cov = np.array([[1.5, 0.2],[0.2, 0.1]])
X = sps.multivariate_normal.rvs(mean = np.zeros(D), cov = cov, size=N)

# %%
plt.scatter(*X.T,alpha=.2);

# %% [markdown]
# ## probabilistic model

# %%
# priors
v_prior = tf.Variable(3., dtype=tf.float64, trainable=False)
W_prior = tf.Variable(np.array([[1., 0.], [0., 1.]]),
                      dtype=tf.float64, trainable=False)
m_prior = tf.Variable(np.array([0.5, 0.5]), dtype=tf.float64, trainable=False)
k_prior = tf.Variable(0.6, dtype=tf.float64, trainable=False)

# %%
#x = MultivariateNormalFull(mu=tf.zeros([n, d]), sigma=tf.stack([tf.eye(d)]*n))
sigma = WishartFull(df=v_prior, scale=W_prior)
mu = MultivariateNormalFull(m_prior, k_prior * sigma)
xn = MultivariateNormalCholesky(tf.reshape(tf.tile(mu, [N]), [N, D]),
                            tf.reshape(tf.tile(sigma, [N, 1]), [N, D, D]),name="Alfred")

# %%
sess = tf.Session()
with sess.as_default():
    init = tf.global_variables_initializer()
    init.run()
    X_sample = xn.sample().eval()
    plt.scatter(*X_sample.T,alpha=.2);

# %%
print('***** PROBABILISTIC MODEL *****')
print('mu: {}'.format(mu))
print('sigma: {}'.format(sigma))
print('xn: {}'.format(xn))
# Out:
# ***** PROBABILISTIC MODEL *****
# mu: <ed.RandomVariable 'MultivariateNormalFull/' shape=(2,) dtype=tf.float64>
# sigma: <ed.RandomVariable 'WishartFull/' shape=(2, 2) dtype=tf.float64>
# xn: <ed.RandomVariable 'Alfred/' shape=(10000, 2) dtype=tf.float64>

# %% [markdown]
# ## variational model

# %% [markdown]
# qmu = MultivariateNormalCholesky(
#     tf.Variable(tf.random_normal([D], dtype=tf.float64), name='v1'),
#     tf.nn.softplus(
#         tf.Variable(tf.random_normal([D, D], dtype=tf.float64), name='v2')))
# qsigma = WishartCholesky(
#     tf.nn.softplus(
#         tf.Variable(tf.random_normal([], dtype=tf.float64), name='v3')),
#     tf.nn.softplus(
#         tf.Variable(tf.random_normal([D, D], dtype=tf.float64), name='v4')))

# %%
m = tf.Variable(tf.random_normal([D], dtype=tf.float64))
covmat = tf.nn.softplus(
        tf.Variable(tf.random_normal([D, D], dtype=tf.float64)))
qmu = MultivariateNormalCholesky(m,covmat)
L = tf.nn.softplus(
        tf.Variable(tf.random_normal([D, D], dtype=tf.float64)))
LLT = tf.matmul(L,L,transpose_b=True)
qsigma = WishartFull(
    tf.nn.softplus(
        tf.Variable(tf.random_normal([], dtype=tf.float64))),
    LLT
    )

# %%
print('***** VARIATIONAL MODEL *****')
print('qmu: {}'.format(qmu))
print('qsigma: {}'.format(qsigma))
# Out:
# ***** VARIATIONAL MODEL *****
# qmu: <ed.RandomVariable 'MultivariateNormalCholesky/' shape=(2,) dtype=tf.float64>
# qsigma: <ed.RandomVariable 'WishartFull_1/' shape=(2, 2) dtype=tf.float64>

# %%
#inference = ed.KLqp({mu: qmu, sigma: qsigma}, data={xn: X})
inference = ed.KLqp({mu: qmu, sigma: qsigma}, data={xn: X})

# %%
# %%debug
# inference.initialize()
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(2)<module>()
#
# ipdb> q
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in initialize(self, n_samples, *args, **kwargs)
#      64     """
#      65     self.n_samples = n_samples
# ---> 66     return super(KLqp, self).initialize(*args, **kwargs)
#      67
#      68   def build_loss_and_gradients(self, var_list):
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/variational_inference.py in initialize(self, optimizer, var_list, use_prettytensor, *args, **kwargs)
#      68         var_list = None
#      69
# ---> 70     self.loss, grads_and_vars = self.build_loss_and_gradients(var_list)
#      71
#      72     if optimizer is None:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_loss_and_gradients(self, var_list)
#     106       #    return build_reparam_entropy_loss_and_gradients(self, var_list)
#     107       else:
# --> 108         return build_reparam_loss_and_gradients(self, var_list)
#     109     else:
#     110       if is_analytic_kl:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_reparam_loss_and_gradients(inference, var_list)
#     351         if isinstance(x, RandomVariable):
#     352           x_copy = copy(x, dict_swap, scope=scope)
# --> 353           x_log_prob = tf.reduce_sum(x_copy.log_prob(dict_swap[x]))
#     354           if x in inference.scale:
#     355             x_log_prob *= inference.scale[x]
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/distribution.py in log_prob(self, value, name, **condition_kwargs)
#     604       value = ops.convert_to_tensor(value, name="value")
#     605       try:
# --> 606         return self._log_prob(value, **condition_kwargs)
#     607       except NotImplementedError as original_exception:
#     608         try:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/distribution_util.py in _fn(*args, **kwargs)
#     675     @functools.wraps(fn)
#     676     def _fn(*args, **kwargs):
# --> 677       return fn(*args, **kwargs)
#     678     if _fn.__doc__ is None:
#     679       _fn.__doc__ = self._additional_note
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/mvn.py in _log_prob(self, x)
#     258     # See Operator base class for notes about shapes compatible with self._cov.
#     259     x = ops.convert_to_tensor(x)
# --> 260     contrib_tensor_util.assert_same_float_dtype((self._mu, x))
#     261
#     262     # _assert_valid_mu asserts that self.mu has same batch shape as self.cov.
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/framework/python/framework/tensor_util.py in assert_same_float_dtype(tensors, dtype)
#      95   """
#      96   if tensors:
# ---> 97     dtype = _assert_same_base_type(tensors, dtype)
#      98   if not dtype:
#      99     dtype = dtypes.float32
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/framework/python/framework/tensor_util.py in _assert_same_base_type(items, expected_type)
#      71             item.name if hasattr(item, 'name') else str(item),
#      72             item_type, expected_type,
# ---> 73             (' as %s' % original_item_str) if original_item_str else ''))
#      74   return expected_type
#      75
#
# ValueError: Variable_8/read:0, type=<dtype: 'float32'>, must be of the same type (<dtype: 'float64'>) as inference_139625060831016/0/Alfred/init/mu:0.

# %%
inference.initialize()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-5020c890c760> in <module>()
# ----> 1 inference.initialize()
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in initialize(self, n_samples, *args, **kwargs)
#      64     """
#      65     self.n_samples = n_samples
# ---> 66     return super(KLqp, self).initialize(*args, **kwargs)
#      67
#      68   def build_loss_and_gradients(self, var_list):
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/variational_inference.py in initialize(self, optimizer, var_list, use_prettytensor, *args, **kwargs)
#      68         var_list = None
#      69
# ---> 70     self.loss, grads_and_vars = self.build_loss_and_gradients(var_list)
#      71
#      72     if optimizer is None:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_loss_and_gradients(self, var_list)
#     106       #    return build_reparam_entropy_loss_and_gradients(self, var_list)
#     107       else:
# --> 108         return build_reparam_loss_and_gradients(self, var_list)
#     109     else:
#     110       if is_analytic_kl:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_reparam_loss_and_gradients(inference, var_list)
#     351         if isinstance(x, RandomVariable):
#     352           x_copy = copy(x, dict_swap, scope=scope)
# --> 353           x_log_prob = tf.reduce_sum(x_copy.log_prob(dict_swap[x]))
#     354           if x in inference.scale:
#     355             x_log_prob *= inference.scale[x]
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/distribution.py in log_prob(self, value, name, **condition_kwargs)
#     604       value = ops.convert_to_tensor(value, name="value")
#     605       try:
# --> 606         return self._log_prob(value, **condition_kwargs)
#     607       except NotImplementedError as original_exception:
#     608         try:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/distribution_util.py in _fn(*args, **kwargs)
#     675     @functools.wraps(fn)
#     676     def _fn(*args, **kwargs):
# --> 677       return fn(*args, **kwargs)
#     678     if _fn.__doc__ is None:
#     679       _fn.__doc__ = self._additional_note
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/mvn.py in _log_prob(self, x)
#     258     # See Operator base class for notes about shapes compatible with self._cov.
#     259     x = ops.convert_to_tensor(x)
# --> 260     contrib_tensor_util.assert_same_float_dtype((self._mu, x))
#     261
#     262     # _assert_valid_mu asserts that self.mu has same batch shape as self.cov.
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/framework/python/framework/tensor_util.py in assert_same_float_dtype(tensors, dtype)
#      95   """
#      96   if tensors:
# ---> 97     dtype = _assert_same_base_type(tensors, dtype)
#      98   if not dtype:
#      99     dtype = dtypes.float32
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/framework/python/framework/tensor_util.py in _assert_same_base_type(items, expected_type)
#      71             item.name if hasattr(item, 'name') else str(item),
#      72             item_type, expected_type,
# ---> 73             (' as %s' % original_item_str) if original_item_str else ''))
#      74   return expected_type
#      75
#
# ValueError: Variable_8/read:0, type=<dtype: 'float32'>, must be of the same type (<dtype: 'float64'>) as inference_139625060831016/0/Alfred/init/mu:0.

# %%
[var.name for var in tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)]
# Out:
# ['Variable:0',
#  'Variable_1:0',
#  'Variable_2:0',
#  'Variable_3:0',
#  'Variable_4:0',
#  'Variable_5:0',
#  'Variable_6:0',
#  'Variable_7:0',
#  'Variable_9:0',
#  'Variable_10:0',
#  'Variable_11:0',
#  'Variable_12:0',
#  'Variable_13:0',
#  'Variable_14:0',
#  'Variable_15:0',
#  'Variable_16:0',
#  'Variable_17:0',
#  'Variable_18:0',
#  'Variable_20:0',
#  'Variable_22:0',
#  'Variable_24:0',
#  'Variable_25:0',
#  'Variable_26:0',
#  'Variable_27:0',
#  'Variable_28:0',
#  'Variable_30:0']

# %%
tf.get_variable_scope()

# %%
Variable_31
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-dbd10c0184b4> in <module>()
# ----> 1 Variable_31
#
# NameError: name 'Variable_31' is not defined

# %%
sess = ed.get_session()
#init = tf.initialize_all_variables()
init = tf.global_variables_initializer()
init.run()

for t in range(5):
    inference.update()
    inference.print_progress(info_dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-b52c8336ad4f> in <module>()
#       5
#       6 for t in range(5):
# ----> 7     inference.update()
#       8     inference.print_progress(info_dict)
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/variational_inference.py in update(self, feed_dict)
#     136
#     137     sess = get_session()
# --> 138     _, t, loss = sess.run([self.train, self.increment_t, self.loss], feed_dict)
#     139
#     140     if self.debug:
#
# AttributeError: 'KLqp' object has no attribute 'train'

# %%
#inference.run(n_iter=3000, n_samples=10, n_minibatch=8)
inference.run(n_iter=2000, n_samples=20,n_print=100)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-52-bad8f3d57fa5> in <module>()
#       1 #inference.run(n_iter=3000, n_samples=10, n_minibatch=8)
# ----> 2 inference.run(n_iter=2000, n_samples=20,n_print=100)
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/inference.py in run(self, variables, use_coordinator, *args, **kwargs)
#     216       Passed into ``initialize``.
#     217     """
# --> 218     self.initialize(*args, **kwargs)
#     219
#     220     if variables is None:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in initialize(self, n_samples, *args, **kwargs)
#      64     """
#      65     self.n_samples = n_samples
# ---> 66     return super(KLqp, self).initialize(*args, **kwargs)
#      67
#      68   def build_loss_and_gradients(self, var_list):
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/variational_inference.py in initialize(self, optimizer, var_list, use_prettytensor, *args, **kwargs)
#      68         var_list = None
#      69
# ---> 70     self.loss, grads_and_vars = self.build_loss_and_gradients(var_list)
#      71
#      72     if optimizer is None:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_loss_and_gradients(self, var_list)
#     106       #    return build_reparam_entropy_loss_and_gradients(self, var_list)
#     107       else:
# --> 108         return build_reparam_loss_and_gradients(self, var_list)
#     109     else:
#     110       if is_analytic_kl:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/inferences/klqp.py in build_reparam_loss_and_gradients(inference, var_list)
#     341
#     342       for z in six.iterkeys(inference.latent_vars):
# --> 343         z_copy = copy(z, dict_swap, scope=scope)
#     344         z_log_prob = tf.reduce_sum(z_copy.log_prob(dict_swap[z]))
#     345         if z in inference.scale:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/util/random_variables.py in copy(org_instance, dict_swap, scope, replace_itself, copy_q)
#     174     kwargs['name'] = new_name
#     175     # Create new random variable with copied arguments.
# --> 176     new_rv = rv.__class__(*args, **kwargs)
#     177     return new_rv
#     178   elif isinstance(org_instance, tf.Tensor):
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/edward/models/random_variable.py in __init__(self, *args, **kwargs)
#      60     # need to temporarily pop value before __init__
#      61     value = kwargs.pop('value', None)
# ---> 62     super(RandomVariable, self).__init__(*args, **kwargs)
#      63     if value is not None:
#      64       self._kwargs['value'] = value  # reinsert (needed for copying)
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/wishart.py in __init__(self, df, scale, cholesky_input_output_matrices, validate_args, allow_nan_stats, name)
#     519           validate_args=validate_args,
#     520           allow_nan_stats=allow_nan_stats,
# --> 521           name=ns)
#     522     self._parameters = parameters
#     523
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3679     try:
#    3680       self.stack.append(default)
# -> 3681       yield default
#    3682     finally:
#    3683       if self._enforce_nesting:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(self, name)
#    2916         new_stack = self.unique_name(name)
#    2917       self._name_stack = new_stack
# -> 2918       yield "" if new_stack is None else new_stack + "/"
#    2919     finally:
#    2920       self._name_stack = old_stack
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/wishart.py in __init__(self, df, scale, cholesky_input_output_matrices, validate_args, allow_nan_stats, name)
#     519           validate_args=validate_args,
#     520           allow_nan_stats=allow_nan_stats,
# --> 521           name=ns)
#     522     self._parameters = parameters
#     523
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/wishart.py in __init__(self, df, scale_operator_pd, cholesky_input_output_matrices, validate_args, allow_nan_stats, name)
#     140                        "dimension of scale matrix (scale.dimension = %s)" %
#     141                        (self._dimension, self._df)))
# --> 142           self._df = control_flow_ops.with_dependencies([assertions], self._df)
#     143     super(_WishartOperatorPD, self).__init__(
#     144         dtype=self._scale_operator_pd.dtype,
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3679     try:
#    3680       self.stack.append(default)
# -> 3681       yield default
#    3682     finally:
#    3683       if self._enforce_nesting:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(self, name)
#    2916         new_stack = self.unique_name(name)
#    2917       self._name_stack = new_stack
# -> 2918       yield "" if new_stack is None else new_stack + "/"
#    2919     finally:
#    2920       self._name_stack = old_stack
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/wishart.py in __init__(self, df, scale_operator_pd, cholesky_input_output_matrices, validate_args, allow_nan_stats, name)
#     140                        "dimension of scale matrix (scale.dimension = %s)" %
#     141                        (self._dimension, self._df)))
# --> 142           self._df = control_flow_ops.with_dependencies([assertions], self._df)
#     143     super(_WishartOperatorPD, self).__init__(
#     144         dtype=self._scale_operator_pd.dtype,
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3679     try:
#    3680       self.stack.append(default)
# -> 3681       yield default
#    3682     finally:
#    3683       if self._enforce_nesting:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(self, name)
#    2916         new_stack = self.unique_name(name)
#    2917       self._name_stack = new_stack
# -> 2918       yield "" if new_stack is None else new_stack + "/"
#    2919     finally:
#    2920       self._name_stack = old_stack
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in name_scope(name, default_name, values)
#    4219   g = _get_graph_from_inputs(values)
#    4220   with g.as_default(), g.name_scope(n) as scope:
# -> 4221     yield scope
#    4222 # pylint: enable=g-doc-return-or-yield
#    4223
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/distributions/python/ops/wishart.py in __init__(self, df, scale_operator_pd, cholesky_input_output_matrices, validate_args, allow_nan_stats, name)
#     123           self._dimension = ops.convert_to_tensor(
#     124               self._scale_operator_pd.get_shape()[-1].value,
# --> 125               dtype=self._scale_operator_pd.dtype, name="dimension")
#     126         df_val = tensor_util.constant_value(self._df)
#     127         dim_val = tensor_util.constant_value(self._dimension)
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#     649       name=name,
#     650       preferred_dtype=preferred_dtype,
# --> 651       as_ref=False)
#     652
#     653
#
# /home/folzd/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     728               "dtype: requested = %s, actual = %s"
#     729               % (error_prefix, conversion_func, base_type,
# --> 730                  dtype.name, ret.dtype.name))
#     731         return ret
#     732   raise TypeError("%sCannot convert %r with type %s to Tensor: "
#
# RuntimeError: dimension: Conversion function <function _constant_tensor_conversion_function at 0x7f896b001c80> for type <class 'object'> returned incompatible dtype: requested = float64_ref, actual = float64

# %%
tmp = qx.sample().eval()

# %%
tf.matmul(qsigma_half,qsigma_half,transpose_b=True).eval()
# Out:
# array([[ 2266.78149414,  -735.15661621],
#        [ -735.15661621,  2742.12915039]], dtype=float32)

# %%
plt.scatter(*tmp.T,alpha=.2);

# %% [markdown]
# http://www.visiondummy.com/2014/04/geometric-interpretation-covariance-matrix/#Covariance_matrix_as_a_linear_transformation
# https://github.com/blei-lab/edward/issues/471
# https://discourse.edwardlib.org
